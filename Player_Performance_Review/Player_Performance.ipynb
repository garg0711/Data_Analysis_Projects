# %% [markdown]
# # Importing Libraries

# %%
#basic operations 
import numpy as np


#for dataframe manipulations
import pandas as pd


#for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns


#for missing values
import missingno as mno


#for date time manipulation 
import datetime


#for interactivity
import ipywidgets as widgets 
from ipywidgets import interact 
from ipywidgets import interact_manual



#setting up the background style for the plots 
plt.style.use("fivethirtyeight")

# %% [markdown]
# # Reading the data

# %%
#reading the data and also checking the computation time 
filepath = "data.csv"
# %time data = pd.read_csv(filepath)


#Lets also check the shape of the dataset

print(data.shape)
# Out:
# Wall time: 226 ms
# (18207, 89)

# %%
# data columns
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# Checking first 5 rows and columns
pd.set_option('display.max_columns', 100)
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Describe the data for Numerical Columns
pd.set_option('display.max_columns',100)
t=data.iloc[:,2:].describe()
t.style.background_gradient(cmap = 'cividis')
# Out:
# <style type="text/css">
# #T_a0f5d_row0_col0, #T_a0f5d_row0_col1, #T_a0f5d_row0_col2, #T_a0f5d_row0_col3, #T_a0f5d_row0_col4, #T_a0f5d_row0_col5, #T_a0f5d_row0_col6, #T_a0f5d_row0_col7, #T_a0f5d_row0_col8, #T_a0f5d_row0_col9, #T_a0f5d_row0_col10, #T_a0f5d_row0_col11, #T_a0f5d_row0_col12, #T_a0f5d_row0_col13, #T_a0f5d_row0_col14, #T_a0f5d_row0_col15, #T_a0f5d_row0_col16, #T_a0f5d_row0_col17, #T_a0f5d_row0_col18, #T_a0f5d_row0_col19, #T_a0f5d_row0_col20, #T_a0f5d_row0_col21, #T_a0f5d_row0_col22, #T_a0f5d_row0_col23, #T_a0f5d_row0_col24, #T_a0f5d_row0_col25, #T_a0f5d_row0_col26, #T_a0f5d_row0_col27, #T_a0f5d_row0_col28, #T_a0f5d_row0_col29, #T_a0f5d_row0_col30, #T_a0f5d_row0_col31, #T_a0f5d_row0_col32, #T_a0f5d_row0_col33, #T_a0f5d_row0_col34, #T_a0f5d_row0_col35, #T_a0f5d_row0_col36, #T_a0f5d_row0_col37, #T_a0f5d_row0_col38, #T_a0f5d_row0_col39, #T_a0f5d_row0_col40, #T_a0f5d_row0_col41 {
#   background-color: #fee838;
#   color: #000000;
# }
# ...

# %%
# Check the Descriptiive stats for categoricaL columns
data.iloc[:,13:].describe(include = 'object')
# Out:
#        Preferred Foot       Work Rate Body Type Real Face Position  \
# count           18159           18159     18159     18159    18147
# unique              2               9        10         2       27
# top             Right  Medium/ Medium    Normal        No       ST
# freq            13948            9810     10595     16505     2152
#
#              Joined Loaned From Contract Valid Until Height  Weight     LS  \
# count         16654        1264                17918  18159   18159  16122
# unique         1736         341                   36     21      57     93
# top     Jul 1, 2018    Atalanta                 2019    6'0  165lbs   61+2
# freq           1538          20                 4819   2881    1483    705
#
#            ST     RS     LW     LF     CF     RF     RW    LAM    CAM    RAM  \
# count   16122  16122  16122  16122  16122  16122  16122  16122  16122  16122
# unique     93     93    105    102    102    102    105    101    101    101
# ...

# %% [markdown]
# # Cleaning Data

# %%
#checking for null values
#Show null values as matrix FIRST HALF

mno.bar(data.iloc[:, :40],
       color = 'blue',
       sort = 'ascending')
plt.title('Missing values Heat Map for first half',fontsize =25)
plt.show()

# %%
#vISUALISE REMAINNG VALUES
mno.bar(data.iloc[:,40:],
       color = 'blue',
       sort = 'ascending')
plt.title('Checking Remaning values')
plt.show()

# %% [markdown]
# # Missing Values Input

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# filling the missing values for the continous variables for DV

data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace=True)

data['Volleys'].fillna(data['Volleys'].mean(), inplace=True)

data['Dribbling'].fillna(data['Dribbling'].mean(), inplace=True)

data['Curve'].fillna(data['Curve'].mean(), inplace=True) 

data['FKAccuracy'].fillna(data['FKAccuracy'].mean(), inplace=True)

data['LongPassing'].fillna(data['LongPassing'].mean(), inplace=True) 

data['BallControl'].fillna(data['BallControl'].mean(), inplace =True)

data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace=True)

data['Finishing'].fillna(data['Finishing'].mean(), inplace=True)

data['Crossing'].fillna(data['Crossing'].mean(), inplace=True) 

data['Weight'].fillna('165lbs', inplace=True)

data['Contract Valid Until'].fillna(2019, inplace =True)

data['Height'].fillna("6'0", inplace = True) 

data['Loaned From'].fillna('None', inplace=True) 

data['Joined'].fillna('Jul 1, 2018', inplace =True)

data['Jersey Number'].fillna(8, inplace =True)

data['Body Type'].fillna('Normal', inplace=True)

data['Position'].fillna('ST', inplace=True) 

data['Club'].fillna('No Club', inplace=True)

data['Work Rate'].fillna('Medium/ Medium', inplace= True)

data['Skill Moves'].fillna(data['Skill Moves'].mean(), inplace=True)

data['Weak Foot'].fillna(3, inplace=True)

data['Preferred Foot'].fillna('Right', inplace=True)

data['International Reputation'].fillna(1, inplace=True)

data['Wage'].fillna('200k', inplace = True)

data['Real Face'].fillna('No', inplace = True)

data.fillna(0, inplace =True)

# %%
#Check for null values
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Feature  Engineering

# %%
def defending(data):
    return int(round((data[['Marking', 'StandingTackle', 'SlidingTackle']].mean()).mean()))

def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve', 'BallControl']].mean()).mean()))

def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning', 'Vision', 'Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 'Agility', 'Reactions']].mean()).mean()))

def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean())) 

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy', 'ShotPower', 'LongShots', 'Penalties']].mean()).mean()))

# %%
# Adding these to our data
data['Defending'] = data.apply(defending, axis=1)
data['General'] = data.apply(general, axis=1)
data['Mental'] = data.apply(mental, axis=1)
data['Passing'] = data.apply(passing, axis=1)
data['Mobility'] = data.apply(mobility, axis=1)
data['Power'] = data.apply(power, axis=1)
data['Rating'] = data.apply(rating, axis=1)
data['Shooting'] = data.apply(shooting, axis=1)

# %%
# Lets check the column names in data after adding these new features
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %% [markdown]
# #  Data Visualization

# %%
# Check the disributions of Scores,
plt.rcParams['figure.figsize'] = (18, 8)

plt.subplot(2, 4, 1)
sns.distplot(data['Defending'], color='violet')
plt.grid()

plt.subplot(2, 4, 2)
sns.distplot(data['General'], color='black')
plt.grid()

plt.subplot(2, 4, 3)
sns.distplot(data['Mental'], color='red')
plt.grid()

plt.subplot(2, 4, 4)
sns.distplot(data['Passing'], color='black')
plt.grid()

plt.subplot(2, 4, 5)
sns.distplot(data['Mobility'], color='green')
plt.grid()

plt.subplot(2, 4, 6)
sns.distplot(data['Power'], color='blue')
plt.grid()

plt.subplot(2, 4, 7)
sns.distplot(data['Shooting'], color='red')
plt.grid()

plt.subplot(2, 4, 8)
sns.distplot(data['Rating'], color='blue')
plt.grid()


plt.suptitle('Score Distributions for Different Abilities')
plt.show()
# Out:
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Comparision of preffered foot 
plt.rcParams['figure.figsize'] = (10, 5)

sns.countplot(data['Preferred Foot'], palette='pink')
plt.title('Most Preferred Foot of Players', fontsize=25)
plt.show()
# Out:
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Plotting a pie chart 

labels = ['1', '2', '3', '4', '5']
sizes = data['International Reputation'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0.1, 0.2, 0.3, 0.5, 0.7]

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(sizes, labels=labels, colors=colors, explode=explode )
plt.title('International Reputation of Players', fontsize=25)
plt.legend()
plt.show()

# %%
data[data['International Reputation'] == 5][['Name', 'Nationality','Overall']].sort_values(by='Overall',
                                                        ascending=False).style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_72273_row0_col2, #T_72273_row1_col2 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_72273_row2_col2 {
#   background-color: #fd9668;
#   color: #000000;
# }
# #T_72273_row3_col2 {
#   background-color: #f1605d;
#   color: #f1f1f1;
# }
# #T_72273_row4_col2 {
#   background-color: #9e2f7f;
#   color: #f1f1f1;
# }
# #T_72273_row5_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72273">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72273_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_72273_level0_col1" class="col_heading level0 col1" >Nationality</th>
#       <th id="T_72273_level0_col2" class="col_heading level0 col2" >Overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72273_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72273_row0_col0" class="data row0 col0" >L. Messi</td>
# ...

# %%
# Plotting a pie chart to represent the share of weak foot players
labels = ['5','4','3','2','1']
size = data['Weak Foot'].value_counts()
colors = plt.cm.Wistia(np.linspace(0,1,5))
explode = [0,0,0,0,0.1]

plt.pie(size,labels = labels,colors = colors, explode = explode , startangle = 90)
plt.title('Distributions of Weak Foot among Players', fontsize = 25)
plt.legend()
plt.show()

# %%
# Diffrent positions acquired by Players
plt.figure(figsize = (13, 15))
plt.style.use('fivethirtyeight')
ax = sns.countplot(y = 'Position', data = data, palette = 'bone' , order=data['Position'].value_counts().index)
ax.set_xlabel(xlabel = 'Diffrent Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 17)
ax.set_title(label = 'Comparision of Position and Players', fontsize = 25)
plt.show()

# %%
# Function for weight cleaning
def extract_value_from(value):
    out = value.replace('lbs', '')
    return float(out)
data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

# %%
# Plotting the distribution of Weight

plt.figure(figsize=(10,11))
sns.displot(data['Weight'],bins =50, color='blue',kde= True)
plt.title("Weight Of Most Players", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Weight Of Most Players')

# %%
# defining a function for cleaning the wage column
def extract_value_from(column):
    out = column.replace("€", "")
    if 'M' in out:
        out = float(out.replace("M", '')) * 1000000
    elif 'K' in out:
        out = float(out.replace('K', '')) * 1000
    return out

#applying the function to the wage and value column

data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))

# %%
#applying the function to the wage and value column
data['Wage'] =  data['Wage'].apply(lambda x: extract_value_from(x))

# %%
# Visualise wage and value
plt.rcParams['figure.figsize'] = (16,5)
plt.subplot(1,2,1)
sns.distplot(data['Value'], color = 'Blue')
plt.title('Distribution of Value of Players' , fontsize =15)

plt.subplot(1,2,2)
sns.distplot(data['Wage'], color = 'Red')
plt.title('Distribution of Wage of Players' , fontsize =15)
# Out:
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Wage of Players')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Skill Moves of the player
plt.figure(figsize = (10,5))

ax = sns.countplot(x='Skill Moves', data= data , palette = 'pastel')
ax.set_title(label = 'Count of Skill Moves')
ax.set_xlabel(xlabel = 'Number of Skill Moves')
ax.set_ylabel(ylabel = 'Count')
plt.show()

# %%
# Diffrent Work Rate of Players

plt.figure(figsize = (15,5))
plt.style.use('fivethirtyeight')

sns.countplot( x = 'Work Rate' ,data = data , palette ='hls')
plt.title('Diffrent Work Rates of Players', fontsize = 16)
plt.xlabel('Work Rates of Players' ,fontsize = 16)
plt.ylabel('Count of Players',fontsize = 16)
plt.xticks(rotation = 45)
plt.show()

# %%
#To show Different potential scores of the players participating in the FIFA 2019
plt.figure(figsize=(16, 4))
plt.style.use("seaborn-paper")

# Subplot 1 - Potential Scores
plt.subplot(1, 2, 1)
x = data['Potential']
ax = sns.distplot(x, bins=58, kde=False, color="y")
ax.set_xlabel(xlabel="Player's Potential Scores", fontsize=16)
ax.set_ylabel(ylabel="Number of Players", fontsize=10)
ax.set_title(label='Histogram of Player Potential Scores', fontsize=15)

# Subplot 2 - Overall Scores
plt.subplot(1, 2, 2)
y = data['Overall']
ax = sns.distplot(y, bins=58, kde=False, color='y')
ax.set_xlabel(xlabel="Player's Overall Scores", fontsize=18)
ax.set_ylabel(ylabel="Number of Players", fontsize=10)
ax.set_title(label="Histogram of Player Overall Scores", fontsize=15)

plt.show()
# Out:
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Vilon plot
plt.rcParams["figure.figsize"] = (20,7)
plt.style.use('seaborn-dark-palette')

sns.boxplot(data['Overall'], data['Age'],hue = data['Preferred Foot'], palette = 'Greys')
plt.title('Comparision of Overall Scores and age W.R.T Preffered Foot', fontsize =20)
plt.show()
# Out:
# C:\Users\atg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Countries with highest number of players to compare their overall scores

data['Nationality'].value_counts().head(10).plot(kind = 'pie', cmap ='inferno',
                                                 startangle=90)
plt.title("Countries with Highest Number of Players")
plt.axis('off')
plt.show()

# %%
# Every Nattions Player and their Weight

some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Weight']]

data_countries['Weight'] = pd.to_numeric(data_countries['Weight'], errors='coerce')

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.violinplot(x=data_countries['Nationality'], y=data_countries['Weight'], palette='Reds')
ax.set_xlabel(xlabel='Countries', fontsize=9)
ax.set_ylabel(ylabel='Weight in lbs', fontsize=9)
ax.set_title(label='Distribution of Weight of Players from Different Countries', fontsize=20)

plt.show()
# Out:
# C:\Users\atg\AppData\Local\Temp\ipykernel_21012\1970791878.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_countries['Weight'] = pd.to_numeric(data_countries['Weight'], errors='coerce')

# %%
# Every Nation Players and their overall scores
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Overall']]

plt.rcParams['figure.figsize'] = (10,3)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['Overall'] , palette ='spring')
ax.set_xlabel(xlabel = 'Countries')
ax.set_ylabel(ylabel = 'Overall Scores')
ax.set_title(label = 'Distribution of overall scores  of Players from Diffrent Countries')
# Out:
# Text(0.5, 1.0, 'Distribution of overall scores  of Players from Diffrent Countries')

# %%
def extract_value_from(s):
    out = s.replace('€', '').replace('K', '000').replace('M', '000000')
    return float(out)
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21012\2393280914.py in <module>
#       2     out = s.replace('€', '').replace('K', '000').replace('M', '000000')
#       3     return float(out)
# ----> 4 data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
#       5 data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ...

# %%
data['Value']
# Out:
# 0        110500000.0
# 1         77000000.0
# 2        118500000.0
# 3         72000000.0
# 4        102000000.0
#             ...
# 18202        60000.0
# 18203        60000.0
# 18204        60000.0
# 18205        60000.0
# 18206        60000.0
# Name: Value, Length: 18207, dtype: object

# %%
# Every Nation Players and their wage
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries)].copy()

# Convert 'Wage' column to numeric data type using .loc
#data_countries.loc[:, 'Wage'] = pd.to_numeric(data_countries['Wage'].str.replace('€', '').str.replace('K', '').str.replace('M', '000'), errors='coerce')

plt.rcParams['figure.figsize'] = (10, 3)
ax = sns.barplot(x=data_countries['Nationality'], y=data_countries['Wage'])
ax.set_xlabel(xlabel='Countries')
ax.set_ylabel(ylabel='Wages')
ax.set_title(label='Distribution of Wages of Players from Different Countries')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21012\1757884219.py in <module>
#       7
#       8 plt.rcParams['figure.figsize'] = (10, 3)
# ----> 9 ax = sns.barplot(x=data_countries['Nationality'], y=data_countries['Wage'])
#      10 ax.set_xlabel(xlabel='Countries')
#      11 ax.set_ylabel(ylabel='Wages')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...

# %%
# Every Nation Players and their International Reputation
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['International Reputation']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.boxenplot(x = data_countries['Nationality'] , y=data_countries['International Reputation'] , palette = 'autumn')
ax.set_xlabel(xlabel='Countries')
ax.set_ylabel(ylabel='International Reputation')
ax.set_title(label='Distribution of International Reputation of Players from Different Countries')
plt.grid()
plt.show()

# %%
# Comparing the performance of left and Right fotted players
# ballcontrol vs dribbling

sns.lmplot(x='BallControl', y='Dribbling', data=data, col="Preferred Foot")
plt.show()

# %% [markdown]
# # Query Analysis

# %% [markdown]
# ###  Best Players  per each position wwith their age,club,nationality based on their Overall Scores

# %%
# Best position of players with their age ,personality, Nationality, Club
data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Position','Name','Age','Club','Nationality','Overall']].sort_values(by = 'Overall', ascending = False).style.background_gradient(cmap = 'Purples')
# Out:
# <style type="text/css">
# #T_df320_row0_col2, #T_df320_row0_col5, #T_df320_row1_col5, #T_df320_row12_col2 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_df320_row1_col2, #T_df320_row2_col5, #T_df320_row4_col2, #T_df320_row14_col2 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_df320_row2_col2, #T_df320_row17_col2, #T_df320_row19_col5 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_df320_row3_col2, #T_df320_row5_col2, #T_df320_row6_col2, #T_df320_row10_col2, #T_df320_row11_col2, #T_df320_row15_col5, #T_df320_row16_col5, #T_df320_row17_col5, #T_df320_row18_col5, #T_df320_row21_col2 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_df320_row3_col5, #T_df320_row4_col5, #T_df320_row5_col5, #T_df320_row6_col5, #T_df320_row7_col5, #T_df320_row16_col2, #T_df320_row23_col2 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_df320_row7_col2, #T_df320_row8_col2 {
#   background-color: #4b1687;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Best Player for each Skill

# %%
# Let's Analyse the skill of player
@interact
def skills(skills=['Defending', 'General', 'Mental', 'Passing', 'Mobility', 'Power', 'Rating', 'Shooting'], score=75):
    return data[data[skills] > score][['Name', 'Nationality', 'Club', 'Overall', skills]].sort_values(
        by=skills,
        ascending=False
    ).head(20).style.background_gradient(cmap='Blues')
# Out:
# interactive(children=(Dropdown(description='skills', options=('Defending', 'General', 'Mental', 'Passing', 'Mo…

# %% [markdown]
# ### Lets make a function to get th list of Top 15 Players from each Country

# %%
#Lets make an interactive function for getting a report of the players country wise

@interact
def country( country = list(data['Nationality'].value_counts().index) ):
    x = data[data['Nationality'] == country] [['Name','Position','Overall','Potential']].sort_values(by = 'Overall' , ascending = False).head(15)
    return x.style.background_gradient(cmap = 'magma')
# Out:
# interactive(children=(Dropdown(description='country', options=('England', 'Germany', 'Spain', 'Argentina', 'Fr…

# %% [markdown]
# ### Lets make a function to get th list of Top 15 Players from each Club

# %%
# Lets make an interactive function to get the  list of top 15 players from each club

@interact
def Club( Club = list(data['Club'].value_counts().index[1:]) ):
    x = data[data['Club'] == Club] [['Name','Position','Overall','Potential']].sort_values(by = 'Overall' , ascending = False).head(15)
    return x.style.background_gradient(cmap = 'magma')
# Out:
# interactive(children=(Dropdown(description='Club', options=('FC Barcelona', 'Burnley', 'AS Monaco', 'Everton',…

# %% [markdown]
# Youngest Player for fifa 2019

# %%
youngest = data[data['Age'] == 16] [['Name','Age','Club','Nationality','Overall']]
youngest.sort_values(by = 'Overall', ascending = False ).head(10).style.background_gradient(cmap = 'Purples')
# Out:
# <style type="text/css">
# #T_636a6_row0_col1, #T_636a6_row1_col1, #T_636a6_row2_col1, #T_636a6_row3_col1, #T_636a6_row4_col1, #T_636a6_row5_col1, #T_636a6_row6_col1, #T_636a6_row7_col1, #T_636a6_row8_col1, #T_636a6_row9_col1, #T_636a6_row9_col4 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_636a6_row0_col4, #T_636a6_row1_col4 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_636a6_row2_col4, #T_636a6_row3_col4 {
#   background-color: #5b3495;
#   color: #f1f1f1;
# }
# #T_636a6_row4_col4, #T_636a6_row5_col4 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_636a6_row6_col4, #T_636a6_row7_col4, #T_636a6_row8_col4 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# </style>
# <table id="T_636a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_636a6_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_636a6_level0_col1" class="col_heading level0 col1" >Age</th>
# ...

# %% [markdown]
# Eldest Player for fifa 2019

# %%
data.sort_values(by = 'Age', ascending = False )[['Name','Age','Club','Nationality','Overall']].head(10).style.background_gradient(cmap = 'Wistia')
# Out:
# <style type="text/css">
# #T_404e6_row0_col1, #T_404e6_row5_col4 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_404e6_row0_col4, #T_404e6_row8_col4 {
#   background-color: #fe9a00;
#   color: #000000;
# }
# #T_404e6_row1_col1, #T_404e6_row2_col1 {
#   background-color: #fe9900;
#   color: #000000;
# }
# #T_404e6_row1_col4, #T_404e6_row9_col1 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_404e6_row2_col4 {
#   background-color: #f7ef38;
#   color: #000000;
# }
# #T_404e6_row3_col1 {
#   background-color: #ffce0a;
#   color: #000000;
# }
# #T_404e6_row3_col4, #T_404e6_row9_col4 {
#   background-color: #ffb300;
#   color: #000000;
# }
# #T_404e6_row4_col1, #T_404e6_row5_col1, #T_404e6_row6_col1, #T_404e6_row7_col1, #T_404e6_row8_col1 {
#   background-color: #faed2d;
#   color: #000000;
# }
# #T_404e6_row4_col4 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_404e6_row6_col4 {
#   background-color: #ffbb00;
#   color: #000000;
# }
# ...

# %% [markdown]
# The Longest Membership in the Club

# %%
now = datetime.datetime.now()

data['Join_year'] = data.Joined.dropna().map(lambda x: x.split(",")[1].split(' ')[1])
data['Years_of_member'] = (data.Join_year.dropna().map(lambda x: now.year - int(x))).astype("int")

membership = data[['Name', 'Club', 'Years_of_member']].sort_values(by='Years_of_member', ascending=False).head(10)
membership.set_index('Name', inplace=True)
membership.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_3f749_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3f749_row1_col1, #T_3f749_row2_col1, #T_3f749_row3_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_3f749_row4_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_3f749_row5_col1, #T_3f749_row6_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_3f749_row7_col1, #T_3f749_row8_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_3f749_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_3f749">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f749_level0_col0" class="col_heading level0 col0" >Club</th>
#       <th id="T_3f749_level0_col1" class="col_heading level0 col1" >Years_of_member</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# Membership of Player from top Clubs

import ipywidgets as widgets
from ipywidgets import interact

@interact
def check(column='Years_of_member', club=['FC Barcelona', 'Real Madrid', 'Chelsea'], membership=4 ):
    return data[(data[column] > membership) & (data['Club'] == club)][['Name', 'Club', 'Years_of_member']].sort_values(by='Years_of_member', ascending=False).style.background_gradient(cmap='magma')
# Out:
# interactive(children=(Text(value='Years_of_member', description='column'), Dropdown(description='club', option…

# %% [markdown]
# ### Defining the feature of players

# %%
# defining the features of players

player_features = ['Acceleration', 'Aggression', 'Agility',
                   'Balance', 'BallControl', 'Composure', 
                   'Crossing', 'Dribbling', 'FKAccuracy',
                   'Finishing', 'GKDiving', 'GKHandling', 
                   'GKKicking', 'GKPositioning', 'GKReflexes', 
                   'HeadingAccuracy', 'Interceptions', 'Jumping',
                   'LongPassing', 'LongShots', 'Marking', 'Penalties']


#Top four features for every position in football
for i,val in data.groupby(data['Position'])[player_features].mean().iterrows():
    print('Position {}: {} ,{}, {}'.format(i,*tuple(val.nlargest(4).index)))
# Out:
# Position CAM: Balance ,Agility, Acceleration
# Position CB: Jumping ,Aggression, HeadingAccuracy
# Position CDM: Aggression ,Jumping, Balance
# Position CF: Agility ,Balance, Acceleration
# Position CM: Balance ,Agility, Acceleration
# Position GK: GKReflexes ,GKDiving, GKPositioning
# Position LAM: Agility ,Balance, Acceleration
# Position LB: Acceleration ,Balance, Agility
# Position LCB: Jumping ,Aggression, HeadingAccuracy
# Position LCM: Balance ,Agility, BallControl
# Position LDM: Aggression ,BallControl, LongPassing
# Position LF: Balance ,Agility, Acceleration
# Position LM: Acceleration ,Agility, Balance
# Position LS: Acceleration ,Agility, Finishing
# Position LW: Acceleration ,Agility, Balance
# Position LWB: Acceleration ,Agility, Balance
# Position RAM: Agility ,Balance, Acceleration
# Position RB: Acceleration ,Balance, Jumping
# Position RCB: Jumping ,Aggression, HeadingAccuracy
# Position RCM: Agility ,Balance, BallControl
# ...
